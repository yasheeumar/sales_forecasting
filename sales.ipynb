# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly.express as px

# %%
superstore = pd.read_csv('C:\c programming\sales forecasting\Superstore.csv')
superstore.shape
# Out:
# (9994, 21)

# %%
superstore.head()
# Out:
#      A`        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  4962  CA-2016-156587    7-3-2016    8-3-2016     First Class    AB-10015
# 1  4963  CA-2016-156587    7-3-2016    8-3-2016     First Class    AB-10015
# 2  4964  CA-2016-156587    7-3-2016    8-3-2016     First Class    AB-10015
# 3  8223  CA-2016-152905   18-2-2016   24-2-2016  Standard Class    AB-10015
# 4  8802  CA-2018-140935  10-11-2018  12-11-2018     First Class    AB-10015
#
#    Customer Name   Segment Country/Region           City  ... Postal Code  \
# 0  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 1  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 2  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 3  Aaron Bergman  Consumer  United States      Arlington  ...     76017.0
# 4  Aaron Bergman  Consumer  United States  Oklahoma City  ...     73120.0
#
#     Region       Product ID         Category Sub-Category  \
# 0     West  FUR-CH-10004477        Furniture       Chairs
# 1     West  OFF-AR-10001427  Office Supplies          Art
# 2     West  OFF-ST-10002344  Office Supplies      Storage
# 3  Central  OFF-ST-10000321  Office Supplies      Storage
# 4  Central  TEC-PH-10000562       Technology       Phones
#
#                                  Product Name    Sales  Quantity  Discount  \
# 0  Global Push Button Manager's Chair, Indigo   48.712         1       0.2
# 1                                  Newell 330   17.940         3       0.0
# 2     Carina 42"Hx23 3/4"W Media Storage Unit  242.940         3       0.0
# 3                          Akro Stacking Bins   12.624         2       0.2
# 4                            Samsung Convoy 3  221.980         2       0.0
#
#     Profit
# 0   5.4801
# 1   4.6644
# 2   4.8588
# 3  -2.5248
# 4  62.1544
#
# [5 rows x 21 columns]

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   A`              9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
#  17  Sales           9994 non-null   float64
#  18  Quantity        9994 non-null   int64
#  19  Discount        9994 non-null   float64
#  20  Profit          9994 non-null   float64
# dtypes: float64(4), int64(2), object(15)
# memory usage: 1.6+ MB

# %%
superstore.columns
# Out:
# Index(['A`', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country/Region', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
superstore.describe()
# Out:
#                 A`   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
superstore["Ship Mode"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
superstore["Segment"].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
state_counts = superstore['State'].value_counts()
colors =['blue','green','orange','yellow','pink','red']
plt.figure(figsize=(10,6))
plt.xticks(rotation='vertical')
state_counts.plot(kind='bar',color=colors)
plt.xlabel("State", fontsize=12)
plt.ylabel('Sales',fontsize=12)
plt.title('State Wise Sales',fontsize=14)
plt.show()

# %%
superstore["Order Date"] = pd.DatetimeIndex(superstore["Order Date"])
superstore["Ship Date"] = pd.DatetimeIndex(superstore["Ship Date"])

# %%
superstore.head()
# Out:
#      A`        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  4962  CA-2016-156587 2016-07-03 2016-08-03     First Class    AB-10015
# 1  4963  CA-2016-156587 2016-07-03 2016-08-03     First Class    AB-10015
# 2  4964  CA-2016-156587 2016-07-03 2016-08-03     First Class    AB-10015
# 3  8223  CA-2016-152905 2016-02-18 2016-02-24  Standard Class    AB-10015
# 4  8802  CA-2018-140935 2018-10-11 2018-12-11     First Class    AB-10015
#
#    Customer Name   Segment Country/Region           City  ... Postal Code  \
# 0  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 1  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 2  Aaron Bergman  Consumer  United States        Seattle  ...     98103.0
# 3  Aaron Bergman  Consumer  United States      Arlington  ...     76017.0
# 4  Aaron Bergman  Consumer  United States  Oklahoma City  ...     73120.0
#
#     Region       Product ID         Category Sub-Category  \
# 0     West  FUR-CH-10004477        Furniture       Chairs
# 1     West  OFF-AR-10001427  Office Supplies          Art
# 2     West  OFF-ST-10002344  Office Supplies      Storage
# 3  Central  OFF-ST-10000321  Office Supplies      Storage
# 4  Central  TEC-PH-10000562       Technology       Phones
#
#                                  Product Name    Sales  Quantity  Discount  \
# 0  Global Push Button Manager's Chair, Indigo   48.712         1       0.2
# 1                                  Newell 330   17.940         3       0.0
# 2     Carina 42"Hx23 3/4"W Media Storage Unit  242.940         3       0.0
# 3                          Akro Stacking Bins   12.624         2       0.2
# 4                            Samsung Convoy 3  221.980         2       0.0
#
#     Profit
# 0   5.4801
# 1   4.6644
# 2   4.8588
# 3  -2.5248
# 4  62.1544
#
# [5 rows x 21 columns]

# %%
def check(superstore):
    l = []
    columns = superstore.columns
    for col in columns:
        dtypes = superstore[col].dtypes
        nunique = superstore[col].nunique()
        sum_null = superstore[col].isnull().sum()

        l.append([col, dtypes, nunique, sum_null])

    superstore_check = pd.DataFrame(l, columns=['column', 'dtypes', 'nunique', 'sum_null'])
    return superstore_check
check(superstore)
# Out:
#             column          dtypes  nunique  sum_null
# 0               A`           int64     9994         0
# 1         Order ID          object     5009         0
# 2       Order Date  datetime64[ns]     1236         0
# 3        Ship Date  datetime64[ns]     1334         0
# 4        Ship Mode          object        4         0
# 5      Customer ID          object      793         0
# 6    Customer Name          object      793         0
# 7          Segment          object        3         0
# 8   Country/Region          object        1         0
# 9             City          object      531         0
# 10           State          object       49         0
# 11     Postal Code         float64      630        11
# 12          Region          object        4         0
# 13      Product ID          object     1862         0
# 14        Category          object        3         0
# 15    Sub-Category          object       17         0
# 16    Product Name          object     1850         0
# 17           Sales         float64     5825         0
# 18        Quantity           int64       14         0
# 19        Discount         float64       12         0
# 20          Profit         float64     7287         0

# %%
superstore[superstore["Postal Code"].isna()]
# Out:
#         A`        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2033  9147  US-2018-165505 2018-01-23 2018-01-27  Standard Class    CB-12535
# 2034  9148  US-2018-165505 2018-01-23 2018-01-27  Standard Class    CB-12535
# 2035  9149  US-2018-165505 2018-01-23 2018-01-27  Standard Class    CB-12535
# 7685  2235  CA-2019-104066 2019-05-12 2019-10-12  Standard Class    QJ-19255
# 7694  9742  CA-2017-117086 2017-08-11 2017-12-11  Standard Class    QJ-19255
# 7781  9387  US-2019-127292 2019-01-19 2019-01-23  Standard Class    RM-19375
# 7782  9388  US-2019-127292 2019-01-19 2019-01-23  Standard Class    RM-19375
# 7783  9389  US-2019-127292 2019-01-19 2019-01-23  Standard Class    RM-19375
# 7784  9390  US-2019-127292 2019-01-19 2019-01-23  Standard Class    RM-19375
# 9048  5275  CA-2017-162887 2017-07-11 2017-09-11    Second Class    SV-20785
# 9771  8799  US-2018-150140 2018-06-04 2018-10-04  Standard Class    VM-21685
#
#          Customer Name      Segment Country/Region        City  ...  \
# 2033  Claudia Bergmann    Corporate  United States  Burlington  ...
# 2034  Claudia Bergmann    Corporate  United States  Burlington  ...
# 2035  Claudia Bergmann    Corporate  United States  Burlington  ...
# 7685      Quincy Jones    Corporate  United States  Burlington  ...
# 7694      Quincy Jones    Corporate  United States  Burlington  ...
# 7781     Raymond Messe     Consumer  United States  Burlington  ...
# 7782     Raymond Messe     Consumer  United States  Burlington  ...
# 7783     Raymond Messe     Consumer  United States  Burlington  ...
# 7784     Raymond Messe     Consumer  United States  Burlington  ...
# 9048  Stewart Visinsky     Consumer  United States  Burlington  ...
# 9771   Valerie Mitchum  Home Office  United States  Burlington  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 2033         NaN    East  TEC-AC-10002926       Technology  Accessories
# 2034         NaN    East  OFF-AR-10003477  Office Supplies          Art
# 2035         NaN    East  OFF-ST-10001526  Office Supplies      Storage
# 7685         NaN    East  TEC-AC-10001013       Technology  Accessories
# 7694         NaN    East  FUR-BO-10004834        Furniture    Bookcases
# 7781         NaN    East  OFF-PA-10000157  Office Supplies        Paper
# 7782         NaN    East  OFF-PA-10001970  Office Supplies        Paper
# 7783         NaN    East  OFF-AP-10000828  Office Supplies   Appliances
# 7784         NaN    East  OFF-EN-10001509  Office Supplies    Envelopes
# 9048         NaN    East  FUR-CH-10000595        Furniture       Chairs
# 9771         NaN    East  TEC-PH-10002555       Technology       Phones
#
#                                            Product Name    Sales  Quantity  \
# 2033              Logitech Wireless Marathon Mouse M705    99.98         2
# 2034                                  4009 Highlighters     8.04         6
# 2035              Iceberg Mobile Mega Data/Printer Cart  1564.29        13
# 7685        Logitech ClearChat Comfort/USB Headset H390   205.03         7
# 7694  Riverside Palais Royal Lawyers Bookcase, Royal...  4404.90         5
# 7781                                          Xerox 191    79.92         4
# 7782                                         Xerox 1881    12.28         1
# 7783                    Avanti 4.4 Cu. Ft. Refrigerator   542.94         3
# 7784                          Poly String Tie Envelopes     2.04         1
# 9048                    Safco Contoured Stacking Chairs   715.20         3
# 9771                Nortel Meridian M5316 Digital phone  1294.75         5
#
#       Discount     Profit
# 2033       0.0    42.9914
# 2034       0.0     2.7336
# 2035       0.0   406.7154
# 7685       0.0    67.6599
# 7694       0.0  1013.1270
# 7781       0.0    37.5624
# 7782       0.0     5.7716
# 7783       0.0   152.0232
# 7784       0.0     0.9588
# 9048       0.0   178.8000
# 9771       0.0   336.6350
#
# [11 rows x 21 columns]

# %%
superstore['Postal Code']=superstore['Postal Code'].fillna(5401.0)

# %%
sns.heatmap(superstore.isnull(),yticklabels= False,cbar="False" ,cmap="Greens")
# Out:
# <Axes: >

# %%
superstore['Year'] = pd.DatetimeIndex(superstore['Order Date']).year
superstore['Month'] = pd.DatetimeIndex(superstore['Order Date']).month
superstore['Day'] = pd.DatetimeIndex(superstore['Order Date']).day

# %%
superstore['Order Date'] = pd.to_datetime(superstore['Order Date'])
superstore['Day of week'] = superstore['Order Date'].dt.strftime('%A')

# %%
superstore[['Order Date' ,'Ship Date' , 'Sales' , 'Year' ,'Month' ,'Day']].hist(bins=20 ,figsize =(20,20))
# Out:
# array([[<Axes: title={'center': 'Order Date'}>,
#         <Axes: title={'center': 'Ship Date'}>],
#        [<Axes: title={'center': 'Sales'}>,
#         <Axes: title={'center': 'Year'}>],
#        [<Axes: title={'center': 'Month'}>,
#         <Axes: title={'center': 'Day'}>]], dtype=object)

# %%
best_cities = superstore.pivot_table(values = "Sales" ,index='City',aggfunc='sum')
best_cities = best_cities.sort_values(by=['Sales'], ascending=False).head(20)
best_cities.reset_index(inplace=True)
best_cities['Sales']=best_cities['Sales'].round(2)
best_cities
# Out:
#              City      Sales
# 0   New York City  256368.16
# 1     Los Angeles  175851.34
# 2         Seattle  119540.74
# 3   San Francisco  112669.09
# 4    Philadelphia  109077.01
# 5         Houston   64504.76
# 6         Chicago   48539.54
# 7       San Diego   47521.03
# 8    Jacksonville   44713.18
# 9     Springfield   43054.34
# 10        Detroit   42446.94
# 11       Columbus   38706.24
# 12         Newark   28576.12
# 13       Columbia   25283.32
# 14      Lafayette   25036.20
# 15        Jackson   24963.86
# 16    San Antonio   21843.53
# 17     Burlington   21668.08
# 18      Arlington   20214.53
# 19         Dallas   20131.93

# %%
fig =plt.figure(figsize = (15,10))
plt.bar(best_cities['City'],best_cities['Sales'],width = 0.4)

plt.xlabel("Best Cities",fontsize=15)
plt.ylabel('Revenue',fontsize=15)
plt.xticks(fontsize=12,rotation=90)
plt.yticks(fontsize=12)

for i , v in enumerate(best_cities['Sales']):
  plt.text(i,v/2,str(v),ha='center', rotation=90,color='white',fontsize=8)
plt.show()

# %%
best_dayofweek = superstore.pivot_table(values = "Sales", index = "Day of week", aggfunc = "sum")
best_dayofweek = best_dayofweek.sort_values (by=['Sales'], ascending=False).head (20)

best_dayofweek.reset_index(inplace=True)

best_dayofweek[ 'Sales']=best_dayofweek ['Sales'].round(2)
best_dayofweek
# Out:
#   Day of week      Sales
# 0     Tuesday  372445.62
# 1   Wednesday  364337.87
# 2      Monday  339910.43
# 3      Sunday  338305.47
# 4    Saturday  301366.49
# 5    Thursday  300500.50
# 6      Friday  280334.48

# %%
fig = plt.figure(figsize = (15, 10))


plt.bar(best_dayofweek[ 'Day of week'], best_dayofweek [ 'Sales'], width = 0.4)

plt.xlabel("Best Day of week", fontsize=15)

plt.ylabel("Revenue", fontsize=15)

plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)
for i, v in enumerate (best_dayofweek['Sales']):
   plt.text(i, v/2, str(v), ha='center', va='center', rotation=90, color='white')

plt.show()

# %%
best_category =superstore.pivot_table(values = "Sales", index = "Category", aggfunc = "sum")

best_category = best_category.sort_values(by =['Sales'], ascending=False).head()

best_category.reset_index(inplace=True)

best_category['Sales' ]=best_category['Sales'].round(2)

best_category
# Out:
#           Category      Sales
# 0       Technology  836154.03
# 1        Furniture  741999.80
# 2  Office Supplies  719047.03

# %%
plt.pie (best_category['Sales'], labels=best_category['Category'], autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
sns.countplot(data=superstore,x="Category", hue='Region')

plt.xticks(rotation=90)

plt.show()

# %%
import matplotlib.pyplot as plt
axis = superstore.groupby('Month')[['Sales']].sum().plot(figsize =(10,5), marker= 'o', color ='red')

axis.set_title('Total Sales Per Month')
plt.figure()

# %%
axis = superstore.groupby('Day')[['Sales']].sum().plot(figsize =(10,5), marker= 'o', color ='blue')

axis.set_title('Total Sales Per Day')
plt.figure()

# %%
axis = superstore.groupby('Year')[['Sales']].sum().plot(figsize =(10,5), marker= 'o', color ='Green')

axis.set_title('Total Sales Per Year')
plt.figure()

# %%
store = superstore.rename(columns = {"Ship Date": "ds", 
                                       "Sales": "y"})
print(store)
# Out:
#         A`        Order ID Order Date         ds       Ship Mode Customer ID  \
# 0     4962  CA-2016-156587 2016-07-03 2016-08-03     First Class    AB-10015
# 1     4963  CA-2016-156587 2016-07-03 2016-08-03     First Class    AB-10015
# 2     4964  CA-2016-156587 2016-07-03 2016-08-03     First Class    AB-10015
# 3     8223  CA-2016-152905 2016-02-18 2016-02-24  Standard Class    AB-10015
# 4     8802  CA-2018-140935 2018-10-11 2018-12-11     First Class    AB-10015
# ...    ...             ...        ...        ...             ...         ...
# 9989  3815  CA-2018-152471 2018-08-07 2018-08-07        Same Day    ZD-21925
# 9990  3816  CA-2018-152471 2018-08-07 2018-08-07        Same Day    ZD-21925
# 9991  5898  CA-2018-167682 2018-03-04 2018-09-04  Standard Class    ZD-21925
# 9992  5899  CA-2018-167682 2018-03-04 2018-09-04  Standard Class    ZD-21925
# 9993  8342  CA-2019-141481 2019-11-06 2019-06-14     First Class    ZD-21925
#
#            Customer Name   Segment Country/Region           City  ...  \
# 0          Aaron Bergman  Consumer  United States        Seattle  ...
# 1          Aaron Bergman  Consumer  United States        Seattle  ...
# 2          Aaron Bergman  Consumer  United States        Seattle  ...
# 3          Aaron Bergman  Consumer  United States      Arlington  ...
# 4          Aaron Bergman  Consumer  United States  Oklahoma City  ...
# ...                  ...       ...            ...            ...  ...
# 9989  Zuschuss Donatelli  Consumer  United States   Jacksonville  ...
# 9990  Zuschuss Donatelli  Consumer  United States   Jacksonville  ...
# 9991  Zuschuss Donatelli  Consumer  United States       Richmond  ...
# 9992  Zuschuss Donatelli  Consumer  United States       Richmond  ...
# 9993  Zuschuss Donatelli  Consumer  United States    Los Angeles  ...
#
#      Sub-Category                                       Product Name        y  \
# 0          Chairs         Global Push Button Manager's Chair, Indigo   48.712
# 1             Art                                         Newell 330   17.940
# 2         Storage            Carina 42"Hx23 3/4"W Media Storage Unit  242.940
# 3         Storage                                 Akro Stacking Bins   12.624
# 4          Phones                                   Samsung Convoy 3  221.980
# ...           ...                                                ...      ...
# 9989       Phones           Jabra SPEAK 410 Multidevice Speakerphone  823.960
# 9990        Paper                                         Xerox 1921   15.984
# 9991  Furnishings                     Seth Thomas 13 1/2" Wall Clock   71.120
# 9992       Phones     Plantronics Voyager Pro HD - Bluetooth Headset  259.960
# 9993   Appliances  Kensington 6 Outlet Guardian Standard Surge Pr...   61.440
#
#      Quantity Discount    Profit  Year  Month  Day  Day of week
# 0           1      0.2    5.4801  2016      7    3       Sunday
# 1           3      0.0    4.6644  2016      7    3       Sunday
# 2           3      0.0    4.8588  2016      7    3       Sunday
# 3           2      0.2   -2.5248  2016      2   18     Thursday
# 4           2      0.0   62.1544  2018     10   11     Thursday
# ...       ...      ...       ...   ...    ...  ...          ...
# 9989        5      0.2   51.4975  2018      8    7      Tuesday
# 9990        2      0.2    4.9950  2018      8    7      Tuesday
# 9991        4      0.0   22.0472  2018      3    4       Sunday
# 9992        4      0.0  124.7808  2018      3    4       Sunday
# 9993        3      0.0   16.5888  2019     11    6    Wednesday
#
# [9994 rows x 25 columns]

# %%
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

superstore = ...

model = Prophet()

model.fit(store)

future = model.make_future_dataframe(periods=365)

predictions = model.predict(future)

fig = plot_plotly(model, predictions)

fig_comp = plot_components_plotly(model, predictions)

fig.show()
fig_comp.show()
# Out:
# 10:17:12 - cmdstanpy - INFO - Chain [1] start processing
# 10:17:13 - cmdstanpy - INFO - Chain [1] done processing
